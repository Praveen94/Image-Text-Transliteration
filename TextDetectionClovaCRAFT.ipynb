# %%
import os
import matplotlib.pyplot as plt
import cv2
import random

# %%
# !git clone https://github.com/clovaai/CRAFT-pytorch.git
# Out:
# Cloning into 'CRAFT-pytorch'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 56 (delta 0), reused 1 (delta 0), pack-reused 53
# Unpacking objects: 100% (56/56), done.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !mkdir ./CRAFT-pytorch/test_img

# %%
# !cp ./drive/My\ Drive/real_Image_dataset_Detection/Image/*.jpg ./CRAFT-pytorch/test_img/

# %%
# !cp ./drive/My\ Drive/craft_mlt_25k.pth ./CRAFT-pytorch/

# %%
os.chdir("./CRAFT-pytorch/")

# %%
# !python test.py --trained_model="./craft_mlt_25k.pth" --test_folder="./test_img" --link_threshold=0.3 --text_threshold=0.7
# Out:
# Loading weights from checkpoint (./craft_mlt_25k.pth)
# elapsed time : 61.145973682403564s

# %%
result_files = [os.path.join("./result",file_) for file_ in os.listdir("./result") if "mask" not in file_ and file_[-3:]!="txt"]

# %%
def read_image(path):
  img = cv2.imread(path)
  img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  return img

# %%
sample_results = random.sample(result_files, 4)
img0 = read_image(sample_results[0])
img1 = read_image(sample_results[1])
img2 = read_image(sample_results[2])
img3 = read_image(sample_results[3])

fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(15,15))
ax[0,0].imshow(img0)
ax[0,1].imshow(img1)
ax[1,0].imshow(img2)
ax[1,1].imshow(img3)
plt.axis('off')
plt.show()
